# %% [markdown]
# # Review Analyzer - LLM Experiments
#
# This notebook demonstrates how to use LLM utilities for the review analyzer project.

# %%
import sys
import os
from pathlib import Path

# Get the project root directory
project_root = Path.cwd().parent.resolve()
sys.path.insert(0, str(project_root))

# Change to project root so relative imports work
os.chdir(project_root)

# Import the LLM utility function
from src.utils.llm_utils import get_llm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 13
#      10 os.chdir(project_root)
#      12 # Import the LLM utility function
# ---> 13 from src.utils.llm_utils import get_llm
#
# File ~/Documents/prototype/review_analyzer/src/utils/llm_utils.py:2
#       1 # LLM utility functions
# ----> 2 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 from src.config.settings import GOOGLE_API_KEY, GEMINI_MODEL, TEMPERATURE
#       6 def get_llm():
#
# ModuleNotFoundError: No module named 'langchain_google_genai'

# %%
# Initialize the LLM
llm = get_llm()
print("LLM initialized successfully!")

# %%
# Invoke the LLM with a prompt
response = llm.invoke("Say hello in one line")

# Display the response
print(response)
